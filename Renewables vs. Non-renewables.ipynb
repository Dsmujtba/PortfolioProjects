# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load renewable and non-renewable power plant datasets
renewables = pd.read_csv('C:/Users/hp/Desktop/renew.csv')
non_renewables = pd.read_csv(r'C:/Users/hp/Desktop/non-renew.csv')
# Out:
#     country country_lo                              name   gppd_idnr  \
# 0       ITA      Italy                          ACCEGLIO  WRI1021706
# 1       ITA      Italy                         ALFONSINE  WRI1021523
# 2       ITA      Italy                        ANAPO C.LE  WRI1002846
# 3       ITA      Italy                           ARDENNO  WRI1021354
# 4       ITA      Italy                             AVISE  WRI1002850
# ..      ...        ...                               ...         ...
# 310     ITA      Italy  Villa Castelli Solar Power Plant  WRI1026451
# 311     ITA      Italy                    Villacidro REC  WKS0062489
# 312     ITA      Italy       Viniamari Solar Power Plant  WRI1026452
# 313     ITA      Italy                      Viterbo KGAL  WKS0062403
# 314     ITA      Italy                          Vittoria  WKS0072931
#
#      capacity_m  latitude  longitude primary_fu  other_fuel  other_fu_1  ...  \
# ...

# %%
# Calculate sum of capacities for renewables and non-renewables
renewable_capacity = renewables['capacity_m'].sum()
non_renewable_capacity = non_renewables['capacity_m'].sum()

# Calculate total capacity
total_capacity = renewable_capacity + non_renewable_capacity

# Calculate proportions
renewable_proportion = renewable_capacity / total_capacity
non_renewable_proportion = non_renewable_capacity / total_capacity

# %%
# Create a pie chart
labels = ['Renewable', 'Non-Renewable']
sizes = [renewable_proportion, non_renewable_proportion]
colors = ['lightgreen', 'lightblue']
explode = (0.1, 0)  # explode the renewable slice
plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Electricity Generation Capacity in Italy (Renewable vs. Non-Renewable)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
