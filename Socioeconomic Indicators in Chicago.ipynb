# %% [markdown]
# ### Import the necessary libraries:

# %%
import pandas as pd
import csv, sqlite3

# %%
# %load_ext sql

# %% [markdown]
# ### Read the CSV files into Pandas DataFrames:

# %%
df1 = pd.read_csv(r'C:\Users\hp\Desktop\ChicagoCensusData.csv')
df2 = pd.read_csv(r'C:\Users\hp\Desktop\ChicagoPublicSchools (1).csv')
df3 = pd.read_csv(r'C:\Users\hp\Desktop\ChicagoCrimeData.csv')

# %%
df3.shape
# Out:
# (533, 21)

# %% [markdown]
# ### Create a connection object to the SQLite database:

# %%
con = sqlite3.connect("socioeconomic.db")
cur = con.cursor()

# %%
# %sql sqlite:///socioeconomic.db

# %% [markdown]
# ### Load the DataFrames into SQL tables:

# %%
df1.to_sql('CENSUS_DATA', con, if_exists='append', index=False)
df2.to_sql('CHICAGO_PUBLIC_SCHOOLS', con, if_exists='append', index=False)
df3.to_sql('CHICAGO_CRIME_DATA', con, if_exists='append', index=False)
# Out:
# 533

# %%
# %sql SELECT * FROM CENSUS_DATA limit 5;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [(1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0)]

# %% [markdown]
# ### Find the total number of crimes recorded in the CRIME table.</p>

# %%
# %sql SELECT COUNT(*) Count FROM CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [(533,)]

# %% [markdown]
# ###  List community areas with per capita income less than 11000.</p>

# %%
# %sql SELECT COMMUNITY_AREA_NAME CommunityAreaName FROM CENSUS_DATA WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %% [markdown]
# ### List all case numbers for crimes involving minors?</p>

# %%
# %sql SELECT CASE_NUMBER CaseNumber FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = 'OFFENSE INVOLVING CHILDREN'
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('HN567387',), ('HR391350',), ('HM768251',), ('HT394616',)]

# %% [markdown]
# ### List all kidnapping crimes involving a child?</p>

# %%
# %sql SELECT PRIMARY_TYPE, DESCRIPTION FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = 'KIDNAPPING'
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('KIDNAPPING', 'CHILD ABDUCTION/STRANGER')]

# %% [markdown]
# ### What kind of crimes were recorded at schools?</p>

# %%
# %%sql
# SELECT DISTINCT(PRIMARY_TYPE) CrimeType
# FROM CHICAGO_CRIME_DATA
# WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# ###  List the average safety score for all types of schools.</p>

# %%
# %sql SELECT * FROM CHICAGO_PUBLIC_SCHOOLS LIMIT 5;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [(610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %%
# %sql SELECT AVG(SAFETY_SCORE) AS AverageSafetyScore FROM CHICAGO_PUBLIC_SCHOOLS
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [(49.50487329434698,)]

# %% [markdown]
# ### List 5 community areas with highest % of households below poverty line.</p>

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME CommunityAreaName,
#        PERCENT_HOUSEHOLDS_BELOW_POVERTY AS Percent
# FROM CENSUS_DATA
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC
# LIMIT 5;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ### Which community area(number) is most crime prone?</p>

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NUMBER, COUNT(*) AS crime_count
# FROM CHICAGO_CRIME_DATA
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY crime_count DESC
# LIMIT 1;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [(25.0, 43)]

# %% [markdown]
# ### Use a sub-query to find the name of the community area with highest hardship index.</p>

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME CommunityAreaName FROM (SELECT COMMUNITY_AREA_NAME, MAX(HARDSHIP_INDEX) FROM CENSUS_DATA)
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Use a sub-query to determine the Community Area Name with most number of crimes?</p>

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NAME
# FROM CENSUS_DATA
# WHERE COMMUNITY_AREA_NUMBER IN (
#   SELECT COMMUNITY_AREA_NUMBER
#   FROM CHICAGO_CRIME_DATA
#   GROUP BY COMMUNITY_AREA_NUMBER
#   ORDER BY COUNT(*) DESC
#   LIMIT 1
# )
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('Austin',)]

# %% [markdown]
# ### List the case number, type of crime and community area for all crimes in community area number 18.</P>

# %%
# %%sql
#
# SELECT
#     DISTINCT(CCD.CASE_NUMBER),
#     CCD.PRIMARY_TYPE,
#     C.COMMUNITY_AREA_NAME,
#     CCD.COMMUNITY_AREA_NUMBER
# FROM CENSUS_DATA C
# JOIN CHICAGO_CRIME_DATA CCD ON
#     C.COMMUNITY_AREA_NUMBER = CCD.COMMUNITY_AREA_NUMBER
# WHERE CCD.COMMUNITY_AREA_NUMBER = 18
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('JA107722', 'OTHER OFFENSE', 'Montclaire', 18.0),
#  ('JA560123', 'CRIMINAL DAMAGE', 'Montclaire', 18.0)]

# %% [markdown]
# ### List all crimes that took place at a school. Include case number, crime type and community name.</p>

# %%
# %%sql
#
# SELECT
#     DISTINCT(CCD.CASE_NUMBER),
#     CCD.PRIMARY_TYPE,
#     C.COMMUNITY_AREA_NAME,
#     CCD.COMMUNITY_AREA_NUMBER
# FROM CENSUS_DATA C
# LEFT JOIN CHICAGO_CRIME_DATA CCD ON
#     C.COMMUNITY_AREA_NUMBER = CCD.COMMUNITY_AREA_NUMBER
# WHERE CCD.LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('HK577020', 'NARCOTICS', 'Rogers Park', 1.0),
#  ('HL725506', 'BATTERY', 'Lincoln Square', 4.0),
#  ('HH639427', 'BATTERY', 'Austin', 25.0),
#  ('HS200939', 'CRIMINAL DAMAGE', 'Austin', 25.0),
#  ('HT315369', 'ASSAULT', 'East Garfield Park', 27.0),
#  ('HP716225', 'BATTERY', 'Douglas', 35.0),
#  ('HL353697', 'BATTERY', 'South Shore', 43.0),
#  ('HS305355', 'NARCOTICS', 'Brighton Park', 58.0),
#  ('HR585012', 'CRIMINAL TRESPASS', 'Ashburn', 70.0),
#  ('JA460432', 'BATTERY', 'Ashburn', 70.0)]

# %% [markdown]
# ### For the communities of Oakland, Armour Square, Edgewater and CHICAGO list the associated community_area_numbers and the case_numbers.</P>

# %%
# %%sql
#
# SELECT
#     DISTINCT(CCD.CASE_NUMBER),
#     C.COMMUNITY_AREA_NAME,
#     C.COMMUNITY_AREA_NUMBER
# FROM CENSUS_DATA C
# FULL OUTER JOIN CHICAGO_CRIME_DATA CCD ON
#     C.COMMUNITY_AREA_NUMBER = CCD.COMMUNITY_AREA_NUMBER
# WHERE COMMUNITY_AREA_NAME IN ('Oakland', 'Armour Square','Edgewater','CHICAGO')
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [(None, 'Armour Square', 34.0),
#  (None, 'Oakland', 36.0),
#  ('HV537004', 'Edgewater', 77.0),
#  ('HM392612', 'Edgewater', 77.0),
#  (None, 'CHICAGO', None)]

# %% [markdown]
# ### Write and execute a SQL query to list the school names, community names and average attendance for communities with a hardship index of 98.</p>

# %%
# %%sql
#
# SELECT
#     DISTINCT(CPS.NAME_OF_SCHOOL),
#     C.COMMUNITY_AREA_NAME,
#     CPS.AVERAGE_STUDENT_ATTENDANCE
# FROM  CHICAGO_PUBLIC_SCHOOLS CPS
# LEFT JOIN CENSUS_DATA C ON
#      CPS.COMMUNITY_AREA_NUMBER = C.COMMUNITY_AREA_NUMBER
# WHERE C.HARDSHIP_INDEX = 98
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('George Washington Carver Military Academy High School', 'Riverdale', '91.60%'),
#  ('George Washington Carver Primary School', 'Riverdale', '90.90%'),
#  ('Ira F Aldridge Elementary School', 'Riverdale', '92.90%'),
#  ('William E B Dubois Elementary School', 'Riverdale', '93.30%')]

# %% [markdown]
# ### Write and execute a SQL query to list all crimes that took place at a school. Include case number, crime type and community name.</P>

# %%
# %%sql
#
# SELECT
#     DISTINCT(CCD.CASE_NUMBER),
#     CCD.PRIMARY_TYPE,
#     C.COMMUNITY_AREA_NAME
# FROM CENSUS_DATA C
# LEFT JOIN CHICAGO_CRIME_DATA CCD ON
#     C.COMMUNITY_AREA_NUMBER = CCD.COMMUNITY_AREA_NUMBER
# WHERE CCD.LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('HK577020', 'NARCOTICS', 'Rogers Park'),
#  ('HL725506', 'BATTERY', 'Lincoln Square'),
#  ('HH639427', 'BATTERY', 'Austin'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'Austin'),
#  ('HT315369', 'ASSAULT', 'East Garfield Park'),
#  ('HP716225', 'BATTERY', 'Douglas'),
#  ('HL353697', 'BATTERY', 'South Shore'),
#  ('HS305355', 'NARCOTICS', 'Brighton Park'),
#  ('HR585012', 'CRIMINAL TRESPASS', 'Ashburn'),
#  ('JA460432', 'BATTERY', 'Ashburn')]

# %% [markdown]
# ### For privacy reasons, you have been asked to create a <font color='blue'>VIEW</font> that enables users to select just the school name and the icon fields from the CHICAGO_PUBLIC_SCHOOLS table. </P>

# %%
# %%sql
#
# CREATE VIEW NEW_CHICAGO
#     (School_Name,
#      Safety_Rating,
#      Family_Rating,
#      Environment_Rating,
#      Instruction_Rating,
#      Leaders_Rating,
#      Teachers_Rating) AS
# SELECT
#     NAME_OF_SCHOOL,
#     Safety_Icon,
#     Family_Involvement_Icon,
#     Environment_Icon,
#     Instruction_Icon,
#     Leaders_Icon,
#     Teachers_Icon
# FROM CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# []

# %% [markdown]
# ### Write and execute a SQL statement that returns all of the columns from the view.</P>

# %%
# %%sql
#
# SELECT *
# FROM NEW_CHICAGO
# LIMIT 5;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('Abraham Lincoln Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 'Average', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('Adlai E Stevenson Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Agustin Lara Elementary Academy', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Air Force Academy High School', 'Average', 'Strong', 'Strong', 'Average', 'Weak', 'Average')]

# %% [markdown]
# ### Write and execute a SQL statement that returns just the school name and leaders rating from the view.</P>

# %%
# %%sql
#
# SELECT
#     School_name,
#     Leaders_Rating
# FROM NEW_CHICAGO;
# Out:
#  * sqlite:///socioeconomic.db
# Done.
# [('Abraham Lincoln Elementary School', 'Weak'),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 'Weak'),
#  ('Adlai E Stevenson Elementary School', 'Weak'),
#  ('Agustin Lara Elementary Academy', 'Weak'),
#  ('Air Force Academy High School', 'Weak'),
#  ('Albany Park Multicultural Academy', 'Weak'),
#  ('Albert G Lane Technical High School', 'Weak'),
#  ('Albert R Sabin Elementary Magnet School', 'Weak'),
#  ('Alcott High School for the Humanities', 'Weak'),
#  ('Alessandro Volta Elementary School', 'Weak'),
#  ('Alexander Graham Bell Elementary School', 'Weak'),
#  ('Alexander Graham Elementary School', 'Weak'),
#  ('Alexander Hamilton Elementary School', 'Weak'),
#  ('Alexander von Humboldt Elementary School', 'Weak'),
#  ('Alex Haley Elementary Academy', 'Weak'),
#  ('Alfred David Kohn Elementary School', 'Weak'),
#  ('Alfred Nobel Elementary School', 'Weak'),
# ...
